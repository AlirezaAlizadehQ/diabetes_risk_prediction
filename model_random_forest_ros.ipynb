# %% [markdown]
# ## import libraries

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import accuracy_score

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## load datasets

# %%
# load random oversampling data
X_ros_train = pd.read_csv('data/ros/X_ros_train.csv')
X_ros_test = pd.read_csv('data/ros/X_ros_test.csv')

y_ros_train = pd.read_csv('data/ros/y_ros_train.csv')
y_ros_test = pd.read_csv('data/ros/y_ros_test.csv')

# load preprocessed original data
X_org_train = pd.read_csv('data/org/X_org_train.csv')
X_org_test = pd.read_csv('data/org/X_org_test.csv')

y_org_train = pd.read_csv('data/org/y_org_train.csv')
y_org_test = pd.read_csv('data/org/y_org_test.csv')

# %% [markdown]
# ## train random forest classifiers

# %% [markdown]
# random forest hyperparameters
#
# - n_estimators: int | number of trees in the forest
# - max_depth: int | maximum depth of the tree
# - min_samples_split : int, float | minimum number of samples required to split an internal node
# - min_samples_leaf: int, float | minimum number of samples required to be at a leaf node
# - max_features: {“sqrt”, “log2”, None}, int or float | number of features when looking for the best split

# %% [markdown]
# ### random forest on random oversampling dataset

# %% [markdown]
# #### finding best n_estimators

# %%
N_ESTIMATORS = np.arange(5, 205, 5)
ACC = []
best_acc = 0
best_n_estimator = 0

# %%
for n_estimator in N_ESTIMATORS:
    model_rf = RandomForestClassifier(
        n_estimators=n_estimator, random_state=7)

    model_rf.fit(X_ros_train, y_ros_train)
    y_pred = model_rf.predict(X_ros_test)
    accuracy = accuracy_score(y_true=y_ros_test, y_pred=y_pred)
    ACC.append(accuracy)

    if accuracy > best_acc:
        best_acc = accuracy
        best_n_estimator = n_estimator

# %%
plt.figure(figsize=(8,6))
plt.plot(N_ESTIMATORS, ACC, marker = "o")
plt.xlabel("Value of n_estimaor")
plt.ylabel("Accuracy Score")
plt.title("Finding the right number of trees")
plt.grid()

# %%
print('the best number of trees in forest is:', best_n_estimator)
print('the best accuracy with {} number of trees in forest is {}'.format(best_n_estimator, best_acc))
# Out:
# the best number of trees in forest is: 10
# the best accuracy with 10 number of trees in forest is 0.9273369624557408

# %% [markdown]
# #### finding best max_features

# %%
MAX_FEATURES = ['log2', None,'sqrt', 0.95, 0.75, 0.5, 0.25, 0.10]
ACC = []
best_acc = 0
best_max_features = 0

# %%
for max_feature in MAX_FEATURES:
    model_rf = RandomForestClassifier(n_estimators=10, 
        max_features=max_feature, random_state=8)

    model_rf.fit(X_ros_train, y_ros_train)
    y_pred = model_rf.predict(X_ros_test)
    accuracy = accuracy_score(y_true=y_ros_test, y_pred=y_pred)
    ACC.append(accuracy)

    if accuracy > best_acc:
        best_acc = accuracy
        best_max_features = max_feature

# %%
plt.figure(figsize=(8, 6))
pd.Series(ACC, MAX_FEATURES).plot(kind="bar",color="darkblue",ylim=(0.5,0.9))
plt.xlabel("Value of max_features")
plt.ylabel("Accuracy Score")
plt.yticks(np.linspace(0.5,1,10))
plt.title("Finding the right max_features of Tree")
# Out:
# Text(0.5, 1.0, 'Finding the right max_features of Tree')

# %%
print('the best max features in forest is:', best_max_features)
print('the best accuracy with {} max features in tree is {}'.format(best_max_features, best_acc))
# Out:
# the best max features in forest is: log2
# the best accuracy with log2 max features in tree is 0.9282338444260735

# %% [markdown]
# #### finding best min_samples_leaf

# %%
MIN_SAMPLES_LEAF = np.arange(5, 55, 5)
ACC = []
best_acc = 0
best_min_samples_leaf = 0

# %%
for min_samples_leaf in MIN_SAMPLES_LEAF:
    model_rf = RandomForestClassifier(n_estimators=10, 
        max_features='log2', min_samples_leaf=min_samples_leaf, random_state=17)

    model_rf.fit(X_ros_train, y_ros_train)
    y_pred = model_rf.predict(X_ros_test)
    accuracy = accuracy_score(y_true=y_ros_test, y_pred=y_pred)
    ACC.append(accuracy)

    if accuracy > best_acc:
        best_acc = accuracy
        best_min_samples_leaf = min_samples_leaf

# %%
plt.figure(figsize=(8,6))
plt.plot(MIN_SAMPLES_LEAF, ACC, marker = "o")
plt.xlabel("Value of min_samples_leaf")
plt.ylabel("Accuracy Score")
plt.title("Finding the right minimum samples leaf")
plt.grid()

# %%
print('the best minimum samples leaf in tree is:', best_min_samples_leaf)
print('the best accuracy with {} minimum samples leaf in tree is {}'.format(best_min_samples_leaf, best_acc))
# Out:
# the best minimum samples leaf in tree is: 5
# the best accuracy with 5 minimum samples leaf in tree is 0.7681677091294785

# %% [markdown]
# #### finding best max_depth

# %%
MAX_DEPTH = [None, 1, 2, 3, 5, 7, 9, 11]
ACC = []
best_acc = 0
best_max_depth = 0

# %%
for max_depth in MAX_DEPTH:
    model_rf = RandomForestClassifier(n_estimators=10, 
        max_features='log2', min_samples_leaf=5 , 
        max_depth=max_depth, random_state=27)

    model_rf.fit(X_ros_train, y_ros_train)
    y_pred = model_rf.predict(X_ros_test)
    accuracy = accuracy_score(y_true=y_ros_test, y_pred=y_pred)
    ACC.append(accuracy)

    if accuracy > best_acc:
        best_acc = accuracy
        best_max_depth = max_depth

# %%
plt.figure(figsize=(8, 6))
pd.Series(ACC, MAX_DEPTH).plot(kind="bar", color="darkblue", ylim=(0.5,0.9))
plt.xlabel("Value of max_depth")
plt.ylabel("Accuracy Score")
plt.yticks(np.linspace(0.5, 1,10))
plt.title("Finding the right maximum depth of Tree")
# Out:
# Text(0.5, 1.0, 'Finding the right maximum depth of Tree')

# %%
print('the best max depth in tree is:', best_max_depth)
print('the best accuracy with {} max depth in tree is {}'.format(best_max_depth, best_acc))
# Out:
# the best max depth in tree is: None
# the best accuracy with None max depth in tree is 0.7688072249691941

# %%
print('on random oversampling the best hyperparameters with accuracy {} are:'.format(best_acc))
print(f'{best_n_estimator = }, {best_max_features = }, {best_min_samples_leaf = }, {best_max_depth = }')
# Out:
# on random oversampling the best hyperparameters with accuracy 0.7688072249691941 are:
# best_n_estimator = 10, best_max_features = 'log2', best_min_samples_leaf = 5, best_max_depth = None

# %% [markdown]
# it is conducted that to obtain the best accuracy on random oversampling the following hyperparameters must be set:
# - n_estimator = 10
# - max_features = 'log2'
